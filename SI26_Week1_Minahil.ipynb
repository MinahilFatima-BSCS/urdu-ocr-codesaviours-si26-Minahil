# %% [markdown]
# <a href="https://colab.research.google.com/github/MinahilFatima-BSCS/urdu-ocr-codesaviours-si26-Minahil/blob/main/SI26_Week1_Minahil.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import required libraries for the project

import os
import pandas as pd
import matplotlib.pyplot as plt

print("Environment setup completed successfully.")
# Out:
# Environment setup completed successfully.
